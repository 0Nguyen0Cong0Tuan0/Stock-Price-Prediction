# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re

# %%
def scrape_article_content(url):
    """
    Scrape the main content of an article from a given URL.
    
    Args:
        url (str): URL of the article.
    
    Returns:
        str: Extracted article content, or empty string if scraping fails.
    """
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        # Send HTTP request
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()  # Raise exception for bad status codes
        
        # Parse HTML
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Remove scripts, styles, and other non-content elements
        for element in soup(['script', 'style', 'nav', 'footer', 'header', 'aside']):
            element.decompose()
        
        # Try common article tags
        content = []
        # Look for article-specific tags first
        article = soup.find('article')
        if article:
            paragraphs = article.find_all('p')
            content = [p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True)]
        
        # Fallback to main content divs or body paragraphs
        if not content:
            main_content = soup.find(['main', 'div'], class_=re.compile('content|article|body', re.I))
            if main_content:
                paragraphs = main_content.find_all('p')
                content = [p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True)]
        
        # Fallback to all paragraphs if no main content found
        if not content:
            paragraphs = soup.find_all('p')
            content = [p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True)]
        
        # Clean and join content
        if content:
            cleaned_content = ' '.join(content).replace('\n', ' ').replace('\r', '')
            cleaned_content = re.sub(r'\s+', ' ', cleaned_content).strip()
            return cleaned_content[:10000]  # Limit to 10,000 chars to avoid excessive length
        
        print(f"No content found for {url}")
        return ''
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return ''
    except Exception as e:
        print(f"Error parsing {url}: {e}")
        return ''

# %%
def process_news_data(input_csv='news_data.csv', output_csv='news_data.csv'):
    """
    Read news_data.csv, scrape article content for each URL, and save to new_data.csv with Content column.
    
    Args:
        input_csv (str): Path to input CSV file.
        output_csv (str): Path to output CSV file.
    """
    # Read input CSV
    try:
        df = pd.read_csv(input_csv)
        print(f"Loaded {len(df)} articles from {input_csv}")
    except FileNotFoundError:
        print(f"Error: {input_csv} not found.")
        return
    except Exception as e:
        print(f"Error reading {input_csv}: {e}")
        return
    
    # Initialize Content column
    df['Content'] = ''
    
    # Scrape content for each URL
    for idx, row in df.iterrows():
        url = row['URL']
        print(f"Scraping article {idx + 1}/{len(df)}: {url}")
        content = scrape_article_content(url)
        df.at[idx, 'Content'] = content
        time.sleep(1)  # Delay to avoid overwhelming servers
    
    # Reorder columns
    df = df[['Ticker', 'Date', 'Title', 'Description', 'Source', 'URL', 'Content']]
    
    # Save to output CSV
    try:
        df.to_csv(output_csv, index=False)
        print(f"Saved updated data with Content column to {output_csv}")
        print(f"Sample of new data:")
        print(df[['Title', 'Source', 'Content']].head())
    except Exception as e:
        print(f"Error saving {output_csv}: {e}")
    
    # Summary
    successful = len(df[df['Content'] != ''])
    print(f"\nSummary: Successfully scraped content for {successful}/{len(df)} articles")

# %%
process_news_data()
# Out:
# Loaded 41 articles from news_data.csv
# Scraping article 1/41: https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-futures-drift-lower-as-apple-amazon-results-signal-trouble-ahead-230801485.html
# Scraping article 2/41: https://qz.com/berkshire-hathaway-q1-2025-earnings-warren-buffett-1851778735
# Scraping article 3/41: https://biztoc.com/x/c3a5ccad569c073d
# Scraping article 4/41: https://biztoc.com/x/c3a5ccad569c073d
# Scraping article 5/41: https://finance.yahoo.com/news/judge-says-ceo-tim-cook-chose-poorly-as-apple-ignored-app-store-order-174755382.html
# Scraping article 6/41: https://economictimes.indiatimes.com/news/international/us/us-stock-market-today-dow-jones-sp-nasdaq-up-heres-top-gainers-top-losers-major-stocks-data-to-consider/articleshow/120798411.cms
# Scraping article 7/41: https://www.businessinsider.com/apple-stock-earnings-call-report-live-updates-2025-5
# Scraping article 8/41: https://finance.yahoo.com/news/stock-shrug-off-recession-alarms-122300844.html
# Scraping article 9/41: https://qz.com/msft-meta-amzn-aapl-tsla-mcd-djia-sp500-nasdaq-stocks-1851778599
# Scraping article 10/41: https://www.etfdailynews.com/2025/05/01/apple-inc-nasdaqaapl-is-lipe-daltons-largest-position/
# Scraping article 11/41: https://www.etfdailynews.com/2025/05/01/prentice-wealth-management-llc-raises-stock-holdings-in-apple-inc-nasdaqaapl/
# Scraping article 12/41: https://www.etfdailynews.com/2025/05/01/marshall-investment-management-llc-takes-position-in-apple-inc-nasdaqaapl/
# Scraping article 13/41: https://www.etfdailynews.com/2025/05/01/apple-inc-nasdaqaapl-stake-lifted-by-thompson-davis-co-inc/
# Scraping article 14/41: https://www.etfdailynews.com/2025/05/01/kintegral-advisory-llc-has-47-05-million-holdings-in-apple-inc-nasdaqaapl/
# Scraping article 15/41: https://www.etfdailynews.com/2025/05/01/camelot-portfolios-llc-has-1-15-million-stock-holdings-in-apple-inc-nasdaqaapl/
# Scraping article 16/41: https://www.etfdailynews.com/2025/05/01/curtis-advisory-group-llc-sells-359-shares-of-apple-inc-nasdaqaapl/
# Scraping article 17/41: https://www.etfdailynews.com/2025/05/01/sigma-planning-corp-decreases-position-in-apple-inc-nasdaqaapl/
# Scraping article 18/41: https://www.etfdailynews.com/2025/05/01/371983-shares-in-apple-inc-nasdaqaapl-purchased-by-fisher-funds-management-ltd/
# Scraping article 19/41: https://www.etfdailynews.com/2025/05/01/apple-inc-nasdaqaapl-shares-acquired-by-element-wealth-llc/
# Scraping article 20/41: https://www.etfdailynews.com/2025/05/01/apple-nasdaqaapl-stock-price-down-0-3-on-analyst-downgrade/
# Scraping article 21/41: https://www.cnbc.com/2025/04/30/microsoft-quiets-critics-delivers-the-kind-of-quarter-worthy-of-its-stock-pop.html
# Scraping article 22/41: https://finance.yahoo.com/news/live/stock-market-today-nasdaq-leads-sp-500-dow-higher-as-microsoft-meta-earnings-reassure-wall-street-133642500.html
# Scraping article 23/41: https://finance.yahoo.com/news/google-ceo-warns-judge-a-breakup-of-search-empire-will-have-many-unintended-consequences-182533297.html
# Scraping article 24/41: https://biztoc.com/x/1b5bfce7c1b1c57a
# Scraping article 25/41: https://www.forbes.com/sites/tomaspray/2025/04/30/more-recessionary-fears-but-the-technical-outlook-gets-stronger/
# Scraping article 26/41: https://economictimes.indiatimes.com/news/international/us/us-stock-market-today-futures-fluctuate-amid-big-tech-earnings-and-trumps-tariff-policies-sp-500-dow-jones-nasdaq-updates-and-magnificent-seven-stock-performance/articleshow/120765162.cms
# Scraping article 27/41: https://finance.yahoo.com/news/apple-inc-aapl-among-best-091638737.html
# Scraping article 28/41: https://finance.yahoo.com/news/apple-earnings-coming-heres-watch-090000718.html
# Scraping article 29/41: https://qz.com/apple-q2-earnings-preview-tariffs-iphone-ipad-tim-cook-1851778363
# Scraping article 30/41: https://www.etfdailynews.com/2025/04/30/ar-asset-management-inc-has-63-million-stock-position-in-apple-inc-nasdaqaapl/
# Scraping article 31/41: https://www.etfdailynews.com/2025/04/30/apple-inc-nasdaqaapl-shares-sold-by-elite-wealth-management-inc/
# Scraping article 32/41: https://www.etfdailynews.com/2025/04/30/apple-inc-nasdaqaapl-stake-trimmed-by-outfitter-financial-llc/
# Scraping article 33/41: https://www.etfdailynews.com/2025/04/30/dahring-cusmano-llc-purchases-shares-of-2406-apple-inc-nasdaqaapl/
# Scraping article 34/41: https://www.etfdailynews.com/2025/04/30/boyd-watterson-asset-management-llc-oh-reduces-holdings-in-apple-inc-nasdaqaapl/
# Scraping article 35/41: https://www.etfdailynews.com/2025/04/30/indie-asset-partners-llc-decreases-stock-holdings-in-apple-inc-nasdaqaapl/
# Scraping article 36/41: https://www.etfdailynews.com/2025/04/30/apple-inc-nasdaqaapl-shares-sold-by-crumly-associates-inc/
# Scraping article 37/41: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_9a7fc338-b36c-433e-b997-a59ab92557aa
# Error fetching https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_9a7fc338-b36c-433e-b997-a59ab92557aa: 401 Client Error: Unauthorized for url: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_9a7fc338-b36c-433e-b997-a59ab92557aa
# Scraping article 38/41: https://www.etfdailynews.com/2025/04/30/technology-stocks-to-watch-today-april-28th/
# Scraping article 39/41: https://www.etfdailynews.com/2025/04/30/apple-nasdaqaapl-shares-up-0-5-after-analyst-upgrade/
# Scraping article 40/41: https://biztoc.com/x/c36708a48519ffa7
# No content found for https://biztoc.com/x/c36708a48519ffa7
# Scraping article 41/41: https://biztoc.com/x/6f8c210205ff420b
# No content found for https://biztoc.com/x/6f8c210205ff420b
# Saved updated data with Content column to new_data.csv
# Sample of new data:
#                                                Title               Source  \
# 0  Stock market today: Dow, S&P 500, Nasdaq futur...  Yahoo Entertainment
# 1  Berkshire Hathaway earnings are coming. Here's...         Quartz India
# 2  As Apple Intelligence Adoption Outperforms Est...           Biztoc.com
# 3  As Apple Intelligence Adoption Outperforms Est...           Biztoc.com
# 4  Judge says CEO Tim Cook 'chose poorly' as Appl...  Yahoo Entertainment
#
#                                              Content
# 0  Unlock stock picks and a broker-level newsfeed...
# 1  Warren Buffett’s Berkshire Hathaway(BRK.A-0.82...
# 2  Less than $10/month! View ALL results for your...
# 3  Less than $10/month! View ALL results for your...
# 4  Unlock stock picks and a broker-level newsfeed...
#
# Summary: Successfully scraped content for 38/41 articles
